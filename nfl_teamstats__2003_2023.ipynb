# %% [markdown]
# # Importando bibliotecas e dataframe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ericcandido/nfl_stats/refs/heads/main/team_stats_2003_2023.csv')
df.head()
# Out:
#    year                  team  wins  losses  win_loss_perc  points  \
# 0  2003  New England Patriots    14       2          0.875     348
# 1  2003        Miami Dolphins    10       6          0.625     311
# 2  2003         Buffalo Bills     6      10          0.375     243
# 3  2003         New York Jets     6      10          0.375     283
# 4  2003      Baltimore Ravens    10       6          0.625     391
#
#    points_opp  points_diff  mov   g  ...  rush_td  rush_yds_per_att  rush_fd  \
# 0         238          110  6.9  16  ...        9               3.4       91
# 1         261           50  3.1  16  ...       14               3.7       99
# 2         279          -36 -2.3  16  ...       13               3.9       96
# 3         299          -16 -1.0  16  ...        8               4.0       78
# 4         281          110  6.9  16  ...       18               4.8      115
#
#    penalties  penalties_yds  pen_fd  score_pct  turnover_pct  exp_pts_tot  \
# ...

# %% [markdown]
# # Análise exploratória

# %%
# Definindo informações do dataframe
df.info()
# mov = average margin of victory
# g = games
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  672 non-null    int64
#  1   team                  672 non-null    object
#  2   wins                  672 non-null    int64
#  3   losses                672 non-null    int64
#  4   win_loss_perc         672 non-null    float64
#  5   points                672 non-null    int64
#  6   points_opp            672 non-null    int64
#  7   points_diff           672 non-null    int64
#  8   mov                   352 non-null    float64
#  9   g                     672 non-null    int64
#  10  total_yards           672 non-null    int64
#  11  plays_offense         672 non-null    int64
#  12  yds_per_play_offense  672 non-null    float64
#  13  turnovers             672 non-null    int64
#  14  fumbles_lost          672 non-null    int64
# ...

# %%
# Visualizando as primeiras linhas do df
df.head(10)
# Out:
#    year                  team  wins  losses  win_loss_perc  points  \
# 0  2003  New England Patriots    14       2          0.875     348
# 1  2003        Miami Dolphins    10       6          0.625     311
# 2  2003         Buffalo Bills     6      10          0.375     243
# 3  2003         New York Jets     6      10          0.375     283
# 4  2003      Baltimore Ravens    10       6          0.625     391
# 5  2003    Cincinnati Bengals     8       8          0.500     346
# 6  2003   Pittsburgh Steelers     6      10          0.375     300
# 7  2003      Cleveland Browns     5      11          0.313     254
# 8  2003    Indianapolis Colts    12       4          0.750     447
# 9  2003      Tennessee Titans    12       4          0.750     435
#
#    points_opp  points_diff  mov   g  ...  rush_td  rush_yds_per_att  rush_fd  \
# 0         238          110  6.9  16  ...        9               3.4       91
# ...

# %%
df.shape
# df.shape mostra consecutivamente linhas/rows e colunas/columns
# Out:
# (672, 35)

# %%
df['team'].value_counts()
# Out:
# team
# New England Patriots        21
# Miami Dolphins              21
# Buffalo Bills               21
# New York Jets               21
# Baltimore Ravens            21
# Cincinnati Bengals          21
# Pittsburgh Steelers         21
# Cleveland Browns            21
# Indianapolis Colts          21
# Tennessee Titans            21
# Jacksonville Jaguars        21
# Houston Texans              21
# Kansas City Chiefs          21
# Denver Broncos              21
# Philadelphia Eagles         21
# New York Giants             21
# Dallas Cowboys              21
# Green Bay Packers           21
# Detroit Lions               21
# Chicago Bears               21
# Minnesota Vikings           21
# Arizona Cardinals           21
# San Francisco 49ers         21
# Atlanta Falcons             21
# Carolina Panthers           21
# New Orleans Saints          21
# Tampa Bay Buccaneers        21
# Seattle Seahawks            21
# Oakland Raiders             17
# Washington Redskins         17
# ...

# %%
df['year'].value_counts()
# Out:
# year
# 2003    32
# 2004    32
# 2005    32
# 2006    32
# 2007    32
# 2008    32
# 2009    32
# 2010    32
# 2011    32
# 2012    32
# 2013    32
# 2014    32
# 2015    32
# 2016    32
# 2017    32
# 2018    32
# 2019    32
# 2020    32
# 2021    32
# 2022    32
# 2023    32
# Name: count, dtype: int64

# %%
renomear_colunas = {
    'g': 'games',
    'mov': 'margin_victory'
}
df.rename(columns = renomear_colunas, inplace = True)
df.columns
# Out:
# Index(['year', 'team', 'wins', 'losses', 'win_loss_perc', 'points',
#        'points_opp', 'points_diff', 'margin_victory', 'games', 'total_yards',
#        'plays_offense', 'yds_per_play_offense', 'turnovers', 'fumbles_lost',
#        'first_down', 'pass_cmp', 'pass_att', 'pass_yds', 'pass_td', 'pass_int',
#        'pass_net_yds_per_att', 'pass_fd', 'rush_att', 'rush_yds', 'rush_td',
#        'rush_yds_per_att', 'rush_fd', 'penalties', 'penalties_yds', 'pen_fd',
#        'score_pct', 'turnover_pct', 'exp_pts_tot', 'ties'],
#       dtype='object')

# %%
df.describe()
# Out:
#               year        wins      losses  win_loss_perc      points  \
# count   672.000000  672.000000  672.000000     672.000000  672.000000
# mean   2013.000000    8.050595    8.050595       0.500246  358.633929
# std       6.059811    3.093255    3.086020       0.191452   72.092050
# min    2003.000000    0.000000    0.000000       0.000000  168.000000
# 25%    2008.000000    6.000000    6.000000       0.375000  305.000000
# 50%    2013.000000    8.000000    8.000000       0.500000  359.000000
# 75%    2018.000000   10.000000   10.000000       0.625000  406.000000
# max    2023.000000   16.000000   16.000000       1.000000  606.000000
#
#        points_opp  points_diff  margin_victory       games  total_yards  ...  \
# count  672.000000   672.000000      352.000000  672.000000   672.000000  ...
# mean   358.633929     0.000000       -0.001136   16.139881  5463.895833  ...
# std     57.889328   100.684601        6.313288    0.347122   628.209466  ...
# ...

# %% [markdown]
# # Limpando e preparando dados

# %%
df.isnull()
# Out:
#       year   team   wins  losses  win_loss_perc  points  points_opp  \
# 0    False  False  False   False          False   False       False
# 1    False  False  False   False          False   False       False
# 2    False  False  False   False          False   False       False
# 3    False  False  False   False          False   False       False
# 4    False  False  False   False          False   False       False
# ..     ...    ...    ...     ...            ...     ...         ...
# 667  False  False  False   False          False   False       False
# 668  False  False  False   False          False   False       False
# 669  False  False  False   False          False   False       False
# 670  False  False  False   False          False   False       False
# 671  False  False  False   False          False   False       False
#
#      points_diff  margin_victory  games  ...  rush_td  rush_yds_per_att  \
# 0          False           False  False  ...    False             False
# ...

# %%
df.isnull().sum()
# Out:
# year                      0
# team                      0
# wins                      0
# losses                    0
# win_loss_perc             0
# points                    0
# points_opp                0
# points_diff               0
# margin_victory          320
# games                     0
# total_yards               0
# plays_offense             0
# yds_per_play_offense      0
# turnovers                 0
# fumbles_lost              0
# first_down                0
# pass_cmp                  0
# pass_att                  0
# pass_yds                  0
# pass_td                   0
# pass_int                  0
# pass_net_yds_per_att      0
# pass_fd                   0
# rush_att                  0
# rush_yds                  0
# rush_td                   0
# rush_yds_per_att          0
# rush_fd                   0
# penalties                 0
# penalties_yds             0
# pen_fd                    0
# score_pct                 0
# turnover_pct              0
# ...

# %%
df['margin_victory'].unique()
# Out:
# array([  6.9,   3.1,  -2.3,  -1. ,  -2.4,  -1.7,  -4.3,  -3.4,  -7.8,
#          9.5,   5. ,  -6.8,  -8. ,   5.4,   1.8,  -5.3,  -9. ,   8.4,
#          3.9,  -3.9,   1.3,   0.9,   2.3,  -7.7,   7.4,   4.8,   2.9,
#        -14.2,  11.1,   4.5,  -4.9,   7.6,   0.1,  -7.1,  10.7,  -1.2,
#         -1.9,  -5.9,   8.3,   3. ,  -7.6,   7.9,  -2.8,  -7. ,  -1.6,
#          2.8,   0.6,  -6.3,   0.2,  -3.6,   1. ,  -0.2,  -0.1,  -4.6,
#        -12.1,   2.6,  -6. ,  -7.2,   4.4,   8.2,  -2.1,  12. ,   5.8,
#        -10.7,   8.6,   4.9,   6.6,  -5.8,   6.8,   4.1,   1.1,   3.6,
#         -5.7,  -2.9,   1.6, -10.2,  11.3,  -4.1,  -4.8, -11.8,   9.3,
#         -0.7,  -1.4,   2.4,  -7.4,   4.2,   6.1,  -6.2,  11.8, -10.3,
#          4.7,  -0.4,  10.8,   5.7,  -2.2,  -8.9,  -0.9,  -4.7,  19.7,
#         -6.4,  -5.4, -10.6,   7.8,  -0.3,   6.7,   0.3,   8. ,  -5.6,
#          8.1,   1.4,   1.5,   9. ,   3.4,  -6.1,   4. ,  -5. ,  -0.6,
# ...

# %%
df[df.isnull().any(axis = 1)]
# Out:
#      year                  team  wins  losses  win_loss_perc  points  \
# 0    2003  New England Patriots    14       2          0.875     348
# 1    2003        Miami Dolphins    10       6          0.625     311
# 2    2003         Buffalo Bills     6      10          0.375     243
# 3    2003         New York Jets     6      10          0.375     283
# 4    2003      Baltimore Ravens    10       6          0.625     391
# ..    ...                   ...   ...     ...            ...     ...
# 667  2023     Carolina Panthers     2      15          0.118     236
# 668  2023   San Francisco 49ers    12       5          0.706     491
# 669  2023      Los Angeles Rams    10       7          0.588     404
# 670  2023      Seattle Seahawks     9       8          0.529     364
# 671  2023     Arizona Cardinals     4      13          0.235     330
#
#      points_opp  points_diff  margin_victory  games  ...  rush_td  \
# 0           238          110             6.9     16  ...        9
# ...

# %%
df['ties'].unique()
# Out:
# array([nan,  0.,  1.])

# %%
# Preenchendo as células nulas de 'tie' com um valor fixo
df['ties'] = df['ties'].fillna('não informado')
# Melhor subsituir por 'não informado' ou 0 ?
df['ties'].unique()
# Out:
# array(['não informado', 0.0, 1.0], dtype=object)
